# %%
# GPU Setup - RTX 3050 (TF 2.10 + CUDA 11.2 + cuDNN 8.1)
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
print("GPUs detected:", gpus)
for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

if not gpus:
    print("WARNING: No GPU found. Check CUDA 11.2 + cuDNN 8.1 are installed.")
# Out:
# GPUs detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Imports
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

IMG_SIZE   = (256, 256)
BATCH_SIZE = 4

# Oil-spill class colour in the RGB palette masks
# (measured from real mask pixels: [254, 0, 124] with anti-alias noise)
OIL_COLOR     = np.array([254,  0, 124], dtype=np.int32)
WATER_COLOR   = np.array([ 51, 221, 255], dtype=np.int32)
LAND_COLOR    = np.array([255, 204,  51], dtype=np.int32)
BG_COLOR      = np.array([  0,   0,   0], dtype=np.int32)
TOLERANCE     = 30          # per-channel tolerance for anti-aliasing

# %%
# Dataset paths  (Windows local, adjust D: drive if needed)
base_dir     = r"D:\oil_spill_detection\data"

train_images = os.path.join(base_dir, "train", "images")
train_masks  = os.path.join(base_dir, "train", "masks")
val_images   = os.path.join(base_dir, "val",   "images")
val_masks    = os.path.join(base_dir, "val",   "masks")
test_images  = os.path.join(base_dir, "test",  "images")
test_masks   = os.path.join(base_dir, "test",  "masks")

# %%
# Mask utilities
def rgb_to_binary_oil(mask_rgb: np.ndarray) -> np.ndarray:
    """
    Convert an RGB palette mask (H,W,3 uint8) to a float32 binary mask (H,W,1).
    Pixel = 1.0  if it matches the OIL_SPILL colour (with TOLERANCE).
    Pixel = 0.0  for water / land / background.
    """
    diff = np.abs(mask_rgb.astype(np.int32) - OIL_COLOR)
    is_oil = np.all(diff <= TOLERANCE, axis=-1)
    return is_oil.astype(np.float32)[..., np.newaxis]


def class_map_from_rgb(mask_rgb: np.ndarray) -> np.ndarray:
    """
    Return an integer class map for visualisation only:
      0 = background (black)
      1 = water      (cyan)
      2 = land       (yellow)
      3 = oil spill  (pink)
    """
    h, w, _ = mask_rgb.shape
    cmap = np.zeros((h, w), dtype=np.uint8)

    def match(color):
        diff = np.abs(mask_rgb.astype(np.int32) - color)
        return np.all(diff <= TOLERANCE, axis=-1)

    cmap[match(WATER_COLOR)] = 1
    cmap[match(LAND_COLOR)]  = 2
    cmap[match(OIL_COLOR)]   = 3
    return cmap


def load_image_mask(image_path, mask_path):
    img      = load_img(image_path, target_size=IMG_SIZE)
    img      = img_to_array(img) / 255.0

    mask_rgb = load_img(mask_path, target_size=IMG_SIZE, color_mode="rgb")
    mask_rgb = img_to_array(mask_rgb).astype(np.uint8)

    binary   = rgb_to_binary_oil(mask_rgb)
    return img.astype(np.float32), binary, mask_rgb   # keep raw rgb for viz

# %%
# Verify mask extraction on one sample BEFORE any training
# This cell answers: "is the binary mask extracting oil correctly?"

sample_img_dir  = train_images
sample_mask_dir = train_masks

img_files  = sorted(os.listdir(sample_img_dir))
mask_files = sorted(os.listdir(sample_mask_dir))

# Pick first sample
img_path  = os.path.join(sample_img_dir,  img_files[0])
mask_path = os.path.join(sample_mask_dir, mask_files[0])

img_np, bin_mask, mask_rgb_np = load_image_mask(img_path, mask_path)
class_map = class_map_from_rgb(mask_rgb_np)

oil_pct = bin_mask.mean() * 100
print(f"Image : {img_files[0]}")
print(f"Oil-spill pixels: {bin_mask.sum():.0f}  ({oil_pct:.2f}% of image)")

# Colour legend for class map
CMAP_COLORS = ["black", "cyan", "gold", "deeppink"]
CMAP_LABELS = ["Background", "Water", "Land", "Oil Spill"]

fig, axes = plt.subplots(1, 4, figsize=(20, 5))

axes[0].imshow(img_np)
axes[0].set_title("Original Image", fontsize=13)
axes[0].axis("off")

axes[1].imshow(mask_rgb_np)
axes[1].set_title("RGB Palette Mask (raw)", fontsize=13)
axes[1].axis("off")

cmap_img = axes[2].imshow(
    class_map,
    cmap=plt.cm.colors.ListedColormap(CMAP_COLORS),
    vmin=0, vmax=3
)
axes[2].set_title("Class Map (decoded)", fontsize=13)
axes[2].axis("off")
patches = [mpatches.Patch(color=c, label=l)
           for c, l in zip(CMAP_COLORS, CMAP_LABELS)]
axes[2].legend(handles=patches, loc="lower right", fontsize=9)

axes[3].imshow(bin_mask.squeeze(), cmap="gray")
axes[3].set_title(f"Binary Oil Mask\n({oil_pct:.2f}% oil)", fontsize=13)
axes[3].axis("off")

plt.suptitle("Mask Extraction Verification", fontsize=15, fontweight="bold")
plt.tight_layout()
plt.show()

# If oil pixels = 0, the colour tolerance or OIL_COLOR may need adjusting.
# Out:
# Image : Oil (1).jpg
# Oil-spill pixels: 588  (0.90% of image)

# %%
# Data augmentation + tf.data pipeline
def augment(img, mask):
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, max_delta=0.1)
    img = tf.image.random_contrast(img, lower=0.9, upper=1.1)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask


def create_dataset(image_dir, mask_dir, batch_size=8,
                   shuffle=True, augment_data=False):
    img_paths  = sorted([
        os.path.join(image_dir, f) for f in os.listdir(image_dir)
        if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ])
    mask_paths = sorted([
        os.path.join(mask_dir, f) for f in os.listdir(mask_dir)
        if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ])
    assert len(img_paths) == len(mask_paths), (
        f"Mismatch: {len(img_paths)} images vs {len(mask_paths)} masks"
    )
    print(f"  Loaded {len(img_paths)} samples from {image_dir}")

    def gen():
        for ip, mp in zip(img_paths, mask_paths):
            img, mask, _ = load_image_mask(ip, mp)
            yield img, mask

    ds = tf.data.Dataset.from_generator(
        gen,
        output_signature=(
            tf.TensorSpec(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), dtype=tf.float32),
            tf.TensorSpec(shape=(IMG_SIZE[0], IMG_SIZE[1], 1), dtype=tf.float32),
        )
    )
    if shuffle:
        ds = ds.shuffle(buffer_size=len(img_paths))
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    return ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)


print("Building datasets...")
train_ds = create_dataset(train_images, train_masks, BATCH_SIZE, shuffle=True,  augment_data=True)
val_ds   = create_dataset(val_images,   val_masks,   BATCH_SIZE, shuffle=False, augment_data=False)
test_ds  = create_dataset(test_images,  test_masks,  BATCH_SIZE, shuffle=False, augment_data=False)
print("Done.")
# Out:
# Building datasets...
#   Loaded 811 samples from D:\oil_spill_detection\data\train\images
#   Loaded 203 samples from D:\oil_spill_detection\data\val\images
#   Loaded 254 samples from D:\oil_spill_detection\data\test\images
# Done.

# %%
# Custom loss & metrics (compatible with TF 2.10)
from tensorflow.keras import backend as K

def dice_coefficient(y_true, y_pred, smooth=1.0):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coefficient(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=False)(y_true, y_pred)
    return bce + dice_loss(y_true, y_pred)

def iou_metric(y_true, y_pred, smooth=1.0):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
# U-Net architecture
from tensorflow.keras import layers, models

def conv_block(x, filters, dropout_rate=0.0):
    x = layers.Conv2D(filters, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    if dropout_rate > 0:
        x = layers.Dropout(dropout_rate)(x)
    return x

def encoder_block(x, filters, dropout_rate=0.0):
    c = conv_block(x, filters, dropout_rate)
    p = layers.MaxPooling2D((2, 2))(c)
    return c, p

def decoder_block(x, skip, filters, dropout_rate=0.0):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters, dropout_rate)
    return x

def build_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)
    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256, dropout_rate=0.3)
    b      = conv_block(p4, 512, dropout_rate=0.4)
    d1     = decoder_block(b,  s4, 256, dropout_rate=0.3)
    d2     = decoder_block(d1, s3, 128)
    d3     = decoder_block(d2, s2, 64)
    d4     = decoder_block(d3, s1, 32)
    outputs = layers.Conv2D(1, 1, activation="sigmoid")(d4)
    return models.Model(inputs, outputs, name="UNet_OilSpill")

model = build_unet()
model.summary()
# Out:
# Model: "UNet_OilSpill"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 256, 256, 32  128        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  re_lu_18 (ReLU)                (None, 256, 256, 32  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 32  9248        ['re_lu_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 256, 256, 32  128        ['conv2d_20[0][0]']
#  ormalization)                  )
#
# ...

# %%
# Compile + callbacks
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=bce_dice_loss,
    metrics=["accuracy", dice_coefficient, iou_metric]
)

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=8, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6),
    tf.keras.callbacks.ModelCheckpoint(
        "oilspill_unet_best.h5", monitor="val_loss", save_best_only=True),
]

# %%
# Train
EPOCHS = 25   # early stopping will cut this short if needed

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# Training curves
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].plot(history.history["accuracy"],         label="Train")
axes[0].plot(history.history["val_accuracy"],     label="Val")
axes[0].set_title("Accuracy"); axes[0].legend(); axes[0].grid(True)

axes[1].plot(history.history["dice_coefficient"],     label="Train")
axes[1].plot(history.history["val_dice_coefficient"], label="Val")
axes[1].set_title("Dice Coefficient"); axes[1].legend(); axes[1].grid(True)

axes[2].plot(history.history["loss"],     label="Train")
axes[2].plot(history.history["val_loss"], label="Val")
axes[2].set_title("Loss (BCE + Dice)"); axes[2].legend(); axes[2].grid(True)

plt.tight_layout(); plt.show()
# Out:
# Epoch 1/25
# 203/203 [==============================] - 152s 353ms/step - loss: 0.8577 - accuracy: 0.7841 - dice_coefficient: 0.5954 - iou_metric: 0.4375 - val_loss: 2.0754 - val_accuracy: 0.4117 - val_dice_coefficient: 0.5003 - val_iou_metric: 0.3742 - lr: 0.0010
# Epoch 2/25
# 203/203 [==============================] - 127s 298ms/step - loss: 0.7706 - accuracy: 0.8069 - dice_coefficient: 0.6390 - iou_metric: 0.4838 - val_loss: 0.8685 - val_accuracy: 0.7939 - val_dice_coefficient: 0.5417 - val_iou_metric: 0.4032 - lr: 0.0010
# Epoch 3/25
# 203/203 [==============================] - 122s 287ms/step - loss: 0.7056 - accuracy: 0.8354 - dice_coefficient: 0.6713 - iou_metric: 0.5174 - val_loss: 1.4084 - val_accuracy: 0.6859 - val_dice_coefficient: 0.3384 - val_iou_metric: 0.2210 - lr: 0.0010
# Epoch 4/25
# ...

# %%
# Evaluate on test set
from sklearn.metrics import (precision_score, recall_score,
                              f1_score, jaccard_score)

def evaluate_test(model, test_ds, threshold=0.5):
    y_true_all, y_pred_all = [], []
    for imgs, masks in test_ds:
        preds     = model.predict(imgs, verbose=0)
        preds_bin = (preds > threshold).astype(np.uint8)
        y_true_all.append(masks.numpy().ravel())
        y_pred_all.append(preds_bin.ravel())

    y_true = np.concatenate(y_true_all)
    y_pred = np.concatenate(y_pred_all)

    results = {
        "Precision":      float(precision_score(y_true, y_pred, zero_division=0)),
        "Recall":         float(recall_score(y_true, y_pred, zero_division=0)),
        "F1 / Dice":      float(f1_score(y_true, y_pred, zero_division=0)),
        "IoU (Jaccard)":  float(jaccard_score(y_true, y_pred, zero_division=0)),
    }
    for k, v in results.items():
        print(f"  {k}: {v:.4f}")
    return results

print("Test set metrics (threshold=0.5):")
test_results = evaluate_test(model, test_ds)
# Out:
# Test set metrics (threshold=0.5):
#   Precision: 0.8216
#   Recall: 0.8499
#   F1 / Dice: 0.8355
#   IoU (Jaccard): 0.7175

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.2 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.2 MB 2.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/11.2 MB 2.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.2 MB 2.0 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.2 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.2 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.2 MB 2.1 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/11.2 MB 2.0 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/11.2 MB 2.0 MB/s eta 0:00:04
# ...

# %%
# Visualise predictions: Original | RGB Mask | Class Map | Binary GT | Prediction
def visualise_predictions(model, image_dir, mask_dir, num_samples=3, threshold=0.5):
    img_paths  = sorted([
        os.path.join(image_dir, f) for f in os.listdir(image_dir)
        if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ])[:num_samples]
    mask_paths = sorted([
        os.path.join(mask_dir, f) for f in os.listdir(mask_dir)
        if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ])[:num_samples]

    CMAP_COLORS = ["black", "cyan", "gold", "deeppink"]
    CMAP_LABELS = ["Background", "Water", "Land", "Oil Spill"]
    cmap_listed = plt.cm.colors.ListedColormap(CMAP_COLORS)

    for ip, mp in zip(img_paths, mask_paths):
        img, bin_mask, mask_rgb = load_image_mask(ip, mp)
        class_map = class_map_from_rgb(mask_rgb)

        inp   = np.expand_dims(img, 0)
        pred  = model.predict(inp, verbose=0)[0, :, :, 0]
        pred_bin = (pred > threshold).astype(np.float32)

        fig, axes = plt.subplots(1, 5, figsize=(25, 5))

        axes[0].imshow(img)
        axes[0].set_title("Original")
        axes[0].axis("off")

        axes[1].imshow(mask_rgb)
        axes[1].set_title("RGB Mask (raw)")
        axes[1].axis("off")

        axes[2].imshow(class_map, cmap=cmap_listed, vmin=0, vmax=3)
        axes[2].set_title("Class Map")
        axes[2].axis("off")
        patches = [mpatches.Patch(color=c, label=l)
                   for c, l in zip(CMAP_COLORS, CMAP_LABELS)]
        axes[2].legend(handles=patches, loc="lower right", fontsize=7)

        axes[3].imshow(bin_mask.squeeze(), cmap="gray")
        axes[3].set_title("Binary GT (oil=white)")
        axes[3].axis("off")

        axes[4].imshow(pred_bin, cmap="gray")
        axes[4].set_title(f"Prediction (thr={threshold})")
        axes[4].axis("off")

        plt.suptitle(os.path.basename(ip), fontsize=11)
        plt.tight_layout()
        plt.show()

visualise_predictions(model, test_images, test_masks, num_samples=3)

# %%
def visualise_predictions(model, image_dir, mask_dir, num_samples=3, threshold=0.5):
    img_paths  = sorted([
        os.path.join(image_dir, f) for f in os.listdir(image_dir)
        if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ])[:num_samples]
    mask_paths = sorted([
        os.path.join(mask_dir, f) for f in os.listdir(mask_dir)
        if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ])[:num_samples]

    CMAP_COLORS = ["black", "cyan", "gold", "deeppink"]
    CMAP_LABELS = ["Background", "Water", "Land", "Oil Spill"]
    cmap_listed = plt.cm.colors.ListedColormap(CMAP_COLORS)

    for ip, mp in zip(img_paths, mask_paths):
        img, bin_mask, mask_rgb = load_image_mask(ip, mp)
        class_map = class_map_from_rgb(mask_rgb)

        inp      = np.expand_dims(img, 0)
        pred     = model.predict(inp, verbose=0)[0, :, :, 0]
        pred_bin = (pred > threshold).astype(np.float32)

        has_spill    = pred_bin.sum() > 0
        spill_pct    = pred_bin.mean() * 100
        confidence   = float(pred[pred_bin == 1].mean()) if has_spill else float(pred.mean())
        label        = "*** OIL SPILL DETECTED ***" if has_spill else "NO OIL SPILL"
        title_color  = "red" if has_spill else "green"
        gt_spill_pct = bin_mask.mean() * 100

        img_uint8  = (img * 255).astype(np.uint8)
        overlay    = img_uint8.copy()
        oil_pixels = pred_bin.astype(bool)
        overlay[oil_pixels] = (
            overlay[oil_pixels] * 0.4 + np.array([255, 30, 30]) * 0.6
        ).astype(np.uint8)

        fig, axes = plt.subplots(1, 6, figsize=(30, 5))

        axes[0].imshow(img)
        axes[0].set_title("Original", fontsize=11)
        axes[0].axis("off")

        axes[1].imshow(mask_rgb)
        axes[1].set_title("RGB Mask (raw)", fontsize=11)
        axes[1].axis("off")

        axes[2].imshow(class_map, cmap=cmap_listed, vmin=0, vmax=3)
        axes[2].set_title("Class Map", fontsize=11)
        axes[2].axis("off")
        patches = [mpatches.Patch(color=c, label=l)
                   for c, l in zip(CMAP_COLORS, CMAP_LABELS)]
        axes[2].legend(handles=patches, loc="lower right", fontsize=7)

        axes[3].imshow(bin_mask.squeeze(), cmap="gray")
        axes[3].set_title(f"Ground Truth\n({gt_spill_pct:.2f}% oil)", fontsize=11)
        axes[3].axis("off")

        axes[4].imshow(pred_bin, cmap="gray")
        axes[4].set_title(f"Prediction Mask\n({spill_pct:.2f}% oil | conf={confidence:.2f})", fontsize=11)
        axes[4].axis("off")

        axes[5].imshow(overlay)
        axes[5].set_title("Overlay\n(red = predicted oil)", fontsize=11)
        axes[5].axis("off")

        fig.suptitle(
            f"{os.path.basename(ip)}    |    {label}    |    "
            f"Spill Area: {spill_pct:.2f}%    |    Confidence: {confidence:.3f}",
            fontsize=13, fontweight="bold", color=title_color
        )
        plt.tight_layout(rect=[0, 0, 1, 0.95])
        plt.show()
        print("-" * 80)

visualise_predictions(model, test_images, test_masks, num_samples=3)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
